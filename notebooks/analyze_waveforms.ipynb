# %%
# autoreload 
# %load_ext autoreload
# %autoreload 2

# %%
import os
import matplotlib.pyplot as plt
from co60.loaders import load_run, load_run_single_trigger, build_run_configs, load_waveforms_for_inspection
# from co60 import bin, calibrate, gates, plot

# %%
DATA_ROOT_19May2026 = r"C:\Users\pomar\OneDrive\Desktop\Javier_Ang_Corr_Project\5-19-2026"

coinc_preamble    = rf"{DATA_ROOT_19May2026}/coincidence/"

# %%
# grab first 50 events from the 90-degree coincidence run

max_events = 5000

wf_19May2026 = load_waveforms_for_inspection(
    fname=f"{coinc_preamble}co60_coincidence_trial_CH1_HV0_300+020_CH2+HV1_437+290_90deg_source_25cm_away_19May2026.dat",
    max_events=max_events,
)

# %%
s_i = 5

for i in range(s_i, s_i + 1):
    plt.plot(wf_19May2026[1]["time"][i], wf_19May2026[1]["voltage"][i], alpha=1, color='C0')

plt.xlabel("Time (ns)")
plt.ylabel("Voltage (V)")
plt.ylim(-0.501, 0.01)
plt.grid(True, alpha=0.3)
plt.title(f"19 May 2026, 90º Trial, Waveform {s_i}, Channel 1")
plt.show()

# %%
for i in range(0, max_events):
    plt.plot(wf_19May2026[2]["time"][i], wf_19May2026[2]["voltage"][i], alpha=0.003, color='C1')

plt.xlabel("Time (ns)")
plt.ylabel("Voltage (V)")
plt.ylim(-0.501, 0.01)
plt.grid(True, alpha=0.3)
plt.title(f"19 May 2026 Trial: First {max_events} Events, Channel 2")
plt.show()
