# %%
# autoreload 
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import matplotlib.pyplot as plt
from co60.loaders import load_run, load_run_single_trigger, build_run_configs, load_waveforms_for_inspection

# %% [markdown]
# # Load in date from: 3 June 2026

# %%
DATA_ROOT_3June2026 = r"C:\Users\pomar\OneDrive\Desktop\Javier_Ang_Corr_Project\co60_angular_correlation\data\06-03-2026"

coinc_preamble_3June2026    = rf"{DATA_ROOT_3June2026}/coincidence/"
ch1_trig_preamble_3June2026 = rf"{DATA_ROOT_3June2026}/ch1_trigger/"
ch2_trig_preamble_3June2026 = rf"{DATA_ROOT_3June2026}/ch2_trigger/"

ANGLES_3June2026 = [90., 105., 115., 125., 135., 145., 155., 165., 180.]

def make_specs_3June2026(preamble: str, trial_label: str) -> list[dict]:
    """To Build the list of {fname, angle} dicts for one trigger type."""
    return [
        {
            "fname": (
                f"{preamble}co60_{trial_label}_CH1_HV0_300+020_CH2+HV1_437+290_{angle:.0f}deg_source_25cm_away_3June2026.dat"
            ),
            "angle": angle,
        }
        for angle in ANGLES_3June2026
    ]

# %%
RUN_CONFIGS_3June2026 = build_run_configs(
    run_specs=make_specs_3June2026(coinc_preamble_3June2026, "coincidence_trial"),
    
    #  `cache_key` should always have this form: {type: coincidence, single trigger}_{date}_{loading method from DRS4}
    cache_key="coincidence_trial_3June2026_load_run",
    load_fn=load_run,
)

CH1_TRIGGER_RUN_CONFIGS_3June2026 = build_run_configs(
    run_specs=make_specs_3June2026(ch1_trig_preamble_3June2026, "CH1_trig_trial"),
    cache_key="CH1_trig_trial_3June2026_load_run_single_trigger",
    load_fn=load_run_single_trigger,
    load_fn_kwargs={"triggering_channel": 1},
)

CH2_TRIGGER_RUN_CONFIGS_3June2026 = build_run_configs(
    run_specs=make_specs_3June2026(ch2_trig_preamble_3June2026, "CH2_trig_trial"),
    cache_key="CH2_trig_trial_3June2026_load_run_single_trigger",
    load_fn=load_run_single_trigger,
    load_fn_kwargs={"triggering_channel": 2},
)
# Out:
# [loaders] No cache found — running load_run for 'coincidence_trial_3June2026_load_run'...
#   loaded angle=90.0°
#   loaded angle=105.0°
#   loaded angle=115.0°
#   loaded angle=125.0°
#   loaded angle=135.0°
#   loaded angle=145.0°
#   loaded angle=155.0°
#   loaded angle=165.0°
#   loaded angle=180.0°
# [loaders] Saved to C:\Users\pomar\OneDrive\Desktop\Javier_Ang_Corr_Project\co60_angular_correlation\cache\coincidence_trial_3June2026_load_run.pkl
# [loaders] No cache found — running load_run_single_trigger for 'CH1_trig_trial_3June2026_load_run_single_trigger'...
#   loaded angle=90.0°
#   loaded angle=105.0°
#   loaded angle=115.0°
#   loaded angle=125.0°
#   loaded angle=135.0°
#   loaded angle=145.0°
#   loaded angle=155.0°
#   loaded angle=165.0°
#   loaded angle=180.0°
# [loaders] Saved to C:\Users\pomar\OneDrive\Desktop\Javier_Ang_Corr_Project\co60_angular_correlation\cache\CH1_trig_trial_3June2026_load_run_single_trigger.pkl
# ...

# %%
max_events = 5000

wf_3June2026 = load_waveforms_for_inspection(
    fname=f"{coinc_preamble_3June2026}co60_coincidence_trial_CH1_HV0_300+020_CH2+HV1_437+290_90deg_source_25cm_away_3June2026.dat",
    max_events=max_events,
)

# %%
# plot channel 1 waveform 0
for i in range(0, max_events):
    plt.plot(wf_3June2026[1]["time"][i], wf_3June2026[1]["voltage"][i], alpha=0.003, color='C0')
 
plt.xlabel("Time (ns)")
plt.ylabel("Voltage (V)")
plt.ylim(-0.501, 0.01)
plt.grid(True, alpha=0.3)
plt.title(f"19 May 2026 Trial: First {max_events} Events, Channel 1")
plt.show()

# %%
for i in range(0, max_events):
    plt.plot(wf_3June2026[2]["time"][i], wf_3June2026[2]["voltage"][i], alpha=0.003, color='C1')

plt.xlabel("Time (ns)")
plt.ylabel("Voltage (V)")
plt.ylim(-0.501, 0.01)
plt.grid(True, alpha=0.3)
plt.title(f"19 May 2026 Trial: First {max_events} Events, Channel 2")
plt.show()

# %% [markdown]
# # Load in data from: 19 May 2026

# %%
DATA_ROOT_19May2026 = r"C:\Users\pomar\OneDrive\Desktop\Javier_Ang_Corr_Project\05-19-2026"

coinc_preamble_19May2026    = rf"{DATA_ROOT_19May2026}/coincidence/"
ch1_trig_preamble_19May2026 = rf"{DATA_ROOT_19May2026}/ch1_trigger/"
ch2_trig_preamble_19May2026 = rf"{DATA_ROOT_19May2026}/ch2_trigger/"

ANGLES_19May2026 = [90., 105., 115., 125., 135., 145., 155., 165., 180.]

def make_specs_19May2026(preamble: str, trial_label: str) -> list[dict]:
    """To Build the list of {fname, angle} dicts for one trigger type."""
    return [
        {
            "fname": (
                f"{preamble}co60_{trial_label}_CH1_HV0_300+020_CH2+HV1_437+290_{angle:.0f}deg_source_25cm_away_19May2026.dat"
            ),
            "angle": angle,
        }
        for angle in ANGLES_19May2026
    ]

# %%
RUN_CONFIGS_19May2026 = build_run_configs(
    run_specs=make_specs_19May2026(coinc_preamble_19May2026, "coincidence_trial"),
    
    #  `cache_key` should always have this form: {type: coincidence, single trigger}_{date}_{loading method from DRS4}
    cache_key="coincidence_trial_19May2026_load_run",
    load_fn=load_run,
)

CH1_TRIGGER_RUN_CONFIGS_19May2026 = build_run_configs(
    run_specs=make_specs_19May2026(ch1_trig_preamble_19May2026, "CH1_trig_trial"),
    cache_key="CH1_trig_trial_19May2026_load_run_single_trigger",
    load_fn=load_run_single_trigger,
    load_fn_kwargs={"triggering_channel": 1},
)

CH2_TRIGGER_RUN_CONFIGS_19May2026 = build_run_configs(
    run_specs=make_specs_19May2026(ch2_trig_preamble_19May2026, "CH2_trig_trial"),
    cache_key="CH2_trig_trial_19May2026_load_run_single_trigger",
    load_fn=load_run_single_trigger,
    load_fn_kwargs={"triggering_channel": 2},
)
# Out:
# [loaders] Cache hit — loading 'coincidence_trial_19May2026_load_run' from C:\Users\pomar\OneDrive\Desktop\Javier_Ang_Corr_Project\co60_angular_correlation\cache\coincidence_trial_19May2026_load_run.pkl
# [loaders] Cache hit — loading 'CH1_trig_trial_19May2026_load_run_single_trigger' from C:\Users\pomar\OneDrive\Desktop\Javier_Ang_Corr_Project\co60_angular_correlation\cache\CH1_trig_trial_19May2026_load_run_single_trigger.pkl
# [loaders] Cache hit — loading 'CH2_trig_trial_19May2026_load_run_single_trigger' from C:\Users\pomar\OneDrive\Desktop\Javier_Ang_Corr_Project\co60_angular_correlation\cache\CH2_trig_trial_19May2026_load_run_single_trigger.pkl

# %%
# grab first 5000 events from the 90-degree coincidence run

max_events = 5000

wf_19May2026 = load_waveforms_for_inspection(
    fname=f"{coinc_preamble_19May2026}co60_coincidence_trial_CH1_HV0_300+020_CH2+HV1_437+290_90deg_source_25cm_away_19May2026.dat",
    max_events=max_events,
)

# %%
# plot channel 1 waveform 0
for i in range(0, max_events):
    plt.plot(wf_19May2026[1]["time"][i], wf_19May2026[1]["voltage"][i], alpha=0.003, color='C0')
 
plt.xlabel("Time (ns)")
plt.ylabel("Voltage (V)")
plt.ylim(-0.501, 0.01)
plt.grid(True, alpha=0.3)
plt.title(f"19 May 2026 Trial: First {max_events} Events, Channel 1")
plt.show()

# %%
for i in range(0, max_events):
    plt.plot(wf_19May2026[2]["time"][i], wf_19May2026[2]["voltage"][i], alpha=0.003, color='C1')

plt.xlabel("Time (ns)")
plt.ylabel("Voltage (V)")
plt.ylim(-0.501, 0.01)
plt.grid(True, alpha=0.3)
plt.title(f"19 May 2026 Trial: First {max_events} Events, Channel 2")
plt.show()

# %% [markdown]
# # Load data in from another date: 15 May 2026

# %%
DATA_ROOT_15May2026 = r"C:\Users\pomar\OneDrive\Desktop\Javier_Ang_Corr_Project\05-15-2026"

coinc_preamble_15May2026    = rf"{DATA_ROOT_15May2026}/"
date_preamble = f''

ANGLES_15May2026 = [90., 115., 135., 155., 180.]

def make_specs_15May2026(preamble: str, trial_label: str) -> list[dict]:
    """Build the list of {fname, angle} dicts for one trigger type."""
    return [
        {
            "fname": (
                f"{preamble}co60_{trial_label}_CH1_HV0_300+020_CH2+HV1_437+290_{angle:.0f}deg_source_10cm_away_15May2026.dat"
            ),
            "angle": angle,
        }
        for angle in ANGLES_15May2026
    ]

RUN_CONFIGS_15May2026 = build_run_configs(
    run_specs=make_specs_15May2026(coinc_preamble_15May2026 , "coincidence_trial"),
    cache_key="coincidence_trial_15May2026_load_run",
    load_fn=load_run,
)
# Out:
# [loaders] Cache hit — loading 'coincidence_trial_15May2026_load_run' from C:\Users\pomar\OneDrive\Desktop\Javier_Ang_Corr_Project\co60_angular_correlation\cache\coincidence_trial_15May2026_load_run.pkl

# %%
# grab first 2000 events from the 90-degree coincidence run

max_events = 5000

wf_15May2026 = load_waveforms_for_inspection(
    fname=f"{coinc_preamble_15May2026}co60_coincidence_trial_CH1_HV0_300+020_CH2+HV1_437+290_90deg_source_10cm_away_15May2026.dat",
    max_events=max_events,
)

# plot channel 1
for i in range(0, max_events):
    plt.plot(wf_15May2026[1]["time"][i], wf_15May2026[1]["voltage"][i], alpha=0.003, color='C0')

plt.xlabel("Time (ns)")
plt.ylabel("Voltage (V)")
plt.ylim(-0.501, 0.01)
plt.grid(True, alpha=0.3)
plt.title(f"15 May 2026 Trial: First {len(wf_15May2026[1]['time'])} Events, Channel 1")
plt.show()

# plot channel 2 
for i in range(0, max_events):
    plt.plot(wf_15May2026[2]["time"][i], wf_15May2026[2]["voltage"][i], alpha=0.003, color='C1')

plt.xlabel("Time (ns)")
plt.ylabel("Voltage (V)")
plt.ylim(-0.501, 0.01)
plt.grid(True, alpha=0.3)
plt.title(f"15 May 2026 Trial: First {len(wf_15May2026[1]['time'])} Events, Channel 2")
plt.show()

# %%
# grab first 2000 events from the 90-degree coincidence run

max_events = 5000

wf_15May2026 = load_waveforms_for_inspection(
    fname=f"{coinc_preamble_15May2026}co60_coincidence_trial_CH1_HV0_300+020_CH2+HV1_437+290_90deg_source_10cm_away_15May2026.dat",
    max_events=max_events,
)

# plot channel 1
for i in range(0, max_events):
    plt.plot(wf_15May2026[1]["time"][i], wf_15May2026[1]["voltage"][i], alpha=0.003, color='C0')

plt.xlabel("Time (ns)")
plt.ylabel("Voltage (V)")
plt.ylim(-0.501, 0.01)
plt.grid(True, alpha=0.3)
plt.title(f"15 May 2026 Trial: First {len(wf_15May2026[1]['time'])} Events, Channel 1")
plt.show()

# plot channel 2 
for i in range(0, max_events):
    plt.plot(wf_15May2026[2]["time"][i], wf_15May2026[2]["voltage"][i], alpha=0.003, color='C1')

plt.xlabel("Time (ns)")
plt.ylabel("Voltage (V)")
plt.ylim(-0.501, 0.01)
plt.grid(True, alpha=0.3)
plt.title(f"15 May 2026 Trial: First {len(wf_15May2026[1]['time'])} Events, Channel 2")
plt.show()

# %% [markdown]
# # Load in latest round of data: 1 June 2026

# %%
DATA_ROOT_1June2026 = r"C:\Users\pomar\OneDrive\Desktop\Javier_Ang_Corr_Project\06-01-2026"

coinc_preamble_1June2026    = rf"{DATA_ROOT_1June2026}/coincidence/"
ch1_trig_preamble_1June2026 = rf"{DATA_ROOT_1June2026}/ch1_trigger/"
ch2_trig_preamble_1June2026 = rf"{DATA_ROOT_1June2026}/ch2_trigger/"

ANGLES_1June2026 = [90., 105., 115., 125., 135., 145., 155., 165., 180.]

def make_specs_1June2026(preamble: str, trial_label: str) -> list[dict]:
    """To Build the list of {fname, angle} dicts for one trigger type."""
    return [
        {
            "fname": (
                f"{preamble}co60_{trial_label}_CH1_HV0_300+020_CH2+HV1_437+290_{angle:.0f}deg_source_25cm_away_1June2026.dat"
            ),
            "angle": angle,
        }
        for angle in ANGLES_1June2026
    ]

# %%
RUN_CONFIGS_1June2026 = build_run_configs(
    run_specs=make_specs_1June2026(coinc_preamble_1June2026, "coincidence_trial"),
    
    #  `cache_key` should always have this form: {type: coincidence, single trigger}_{date}_{loading method from DRS4}
    cache_key="coincidence_trial_1June2026_load_run",
    load_fn=load_run,
)

CH1_TRIGGER_RUN_CONFIGS_1June2026 = build_run_configs(
    run_specs=make_specs_1June2026(ch1_trig_preamble_1June2026, "CH1_trig_trial"),
    cache_key="CH1_trig_trial_1June2026_load_run_single_trigger",
    load_fn=load_run_single_trigger,
    load_fn_kwargs={"triggering_channel": 1},
)

CH2_TRIGGER_RUN_CONFIGS_1June2026 = build_run_configs(
    run_specs=make_specs_1June2026(ch2_trig_preamble_1June2026, "CH2_trig_trial"),
    cache_key="CH2_trig_trial_1June2026_load_run_single_trigger",
    load_fn=load_run_single_trigger,
    load_fn_kwargs={"triggering_channel": 2},
)
# Out:
# [loaders] Cache hit — loading 'coincidence_trial_1June2026_load_run' from C:\Users\pomar\OneDrive\Desktop\Javier_Ang_Corr_Project\co60_angular_correlation\cache\coincidence_trial_1June2026_load_run.pkl
# [loaders] Cache hit — loading 'CH1_trig_trial_1June2026_load_run_single_trigger' from C:\Users\pomar\OneDrive\Desktop\Javier_Ang_Corr_Project\co60_angular_correlation\cache\CH1_trig_trial_1June2026_load_run_single_trigger.pkl
# [loaders] Cache hit — loading 'CH2_trig_trial_1June2026_load_run_single_trigger' from C:\Users\pomar\OneDrive\Desktop\Javier_Ang_Corr_Project\co60_angular_correlation\cache\CH2_trig_trial_1June2026_load_run_single_trigger.pkl

# %%
max_events = 5000

wf_1June2026 = load_waveforms_for_inspection(
    fname=f"{coinc_preamble_1June2026}co60_coincidence_trial_CH1_HV0_300+020_CH2+HV1_437+290_90deg_source_25cm_away_1June2026.dat",
    max_events=max_events,
)

# %%
# plot channel 1 waveform 0
for i in range(0, max_events):
    plt.plot(wf_1June2026[1]["time"][i], wf_1June2026[1]["voltage"][i], alpha=0.003, color='C0')
 
plt.xlabel("Time (ns)")
plt.ylabel("Voltage (V)")
plt.ylim(-0.501, 0.01)
plt.grid(True, alpha=0.3)
plt.title(f"1 June 2026 Trial: First {max_events} Events, Channel 1")
plt.show()

# %%
for i in range(0, max_events):
    plt.plot(wf_1June2026[2]["time"][i], wf_1June2026[2]["voltage"][i], alpha=0.003, color='C1')

plt.xlabel("Time (ns)")
plt.ylabel("Voltage (V)")
plt.ylim(-0.501, 0.01)
plt.grid(True, alpha=0.3)
plt.title(f"1 June 2026 Trial: First {max_events} Events, Channel 2")
plt.show()
